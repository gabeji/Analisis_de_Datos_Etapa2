# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
dataframe = pd.read_csv("c:/PruebasAnalisis/framingham.csv")
dataframe.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
dataframe.describe()
# Out:
#               male          age    education  currentSmoker   cigsPerDay  \
# count  4238.000000  4238.000000  4133.000000    4238.000000  4209.000000
# mean      0.429212    49.584946     1.978950       0.494101     9.003089
# std       0.495022     8.572160     1.019791       0.500024    11.920094
# min       0.000000    32.000000     1.000000       0.000000     0.000000
# 25%       0.000000    42.000000     1.000000       0.000000     0.000000
# 50%       0.000000    49.000000     2.000000       0.000000     0.000000
# 75%       1.000000    56.000000     3.000000       1.000000    20.000000
# max       1.000000    70.000000     4.000000       1.000000    70.000000
#
#             BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count  4185.000000      4238.000000   4238.000000  4238.000000  4188.000000
# mean      0.029630         0.005899      0.310524     0.025720   236.721585
# std       0.169584         0.076587      0.462763     0.158316    44.590334
# ...

# %%
print(dataframe.groupby('male').size())
# Out:
# male
# 0    2419
# 1    1819
# dtype: int64

# %%
dataframe.drop(['male'],1).hist()
plt.show()
# Out:
# C:\Users\esmon\AppData\Local\Temp\ipykernel_8432\3095986680.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   dataframe.drop(['male'],1).hist()

# %%
sb.pairplot(dataframe.dropna(), hue='male',size=4,vars=["diabetes", "BMI","totChol","glucose"],kind='reg')
# Out:
# C:\Users\esmon\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
X = np.array(dataframe.drop(['male'],1))
y = np.array(dataframe['male'])
X.shape
# Out:
# C:\Users\esmon\AppData\Local\Temp\ipykernel_8432\2888697229.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = np.array(dataframe.drop(['male'],1))
# (4238, 15)

# %%
model = linear_model.LogisticRegression()
model.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 model = linear_model.LogisticRegression()
# ----> 2 model.fit(X,y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1207, in LogisticRegression.fit(self, X, y, sample_weight)
#    1204 else:
#    1205     _dtype = [np.float64, np.float32]
# -> 1207 X, y = self._validate_data(
#    1208     X,
#    1209     y,
#    1210     accept_sparse="csr",
# ...

# %%
predictions = model.predict(X)
print(predictions)[0:5]
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 predictions = model.predict(X)
#       2 print(predictions)[0:5]
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:451, in LinearClassifierMixin.predict(self, X)
#     437 """
#     438 Predict class labels for samples in X.
#     439
#    (...)
#     448     Vector containing the class labels for each sample.
#     449 """
#     450 xp, _ = get_namespace(X)
# --> 451 scores = self.decision_function(X)
#     452 if len(scores.shape) == 1:
#     453     indices = xp.astype(scores > 0, int)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:429, in LinearClassifierMixin.decision_function(self, X)
#     410 def decision_function(self, X):
#     411     """
#     412     Predict confidence scores for samples.
#     413
#    (...)
# ...

# %%
model.score(X,y)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model.score(X,y)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:705, in ClassifierMixin.score(self, X, y, sample_weight)
#     680 """
#     681 Return the mean accuracy on the given test data and labels.
#     682
#    (...)
#     701     Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     702 """
#     703 from .metrics import accuracy_score
# --> 705 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:451, in LinearClassifierMixin.predict(self, X)
#     437 """
#     438 Predict class labels for samples in X.
#     439
#    (...)
#     448     Vector containing the class labels for each sample.
#     449 """
#     450 xp, _ = get_namespace(X)
# --> 451 scores = self.decision_function(X)
# ...

# %%
validation_size = 0.20
seed = 7
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, y, test_size=validation_size, random_state=seed)

# %%
name='Logistic Regression'
kfold = model_selection.KFold(n_splits=10, random_state=seed)
cv_results = model_selection.cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
print(msg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 name='Logistic Regression'
# ----> 2 kfold = model_selection.KFold(n_splits=10, random_state=seed)
#       3 cv_results = model_selection.cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
#       4 msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:476, in KFold.__init__(self, n_splits, shuffle, random_state)
#     475 def __init__(self, n_splits=5, *, shuffle=False, random_state=None):
# --> 476     super().__init__(n_splits=n_splits, shuffle=shuffle, random_state=random_state)
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:331, in _BaseKFold.__init__(self, n_splits, shuffle, random_state)
# ...

# %%
predictions = model.predict(X_validation)
print(accuracy_score(Y_validation, predictions))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 predictions = model.predict(X_validation)
#       2 print(accuracy_score(Y_validation, predictions))
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:451, in LinearClassifierMixin.predict(self, X)
#     437 """
#     438 Predict class labels for samples in X.
#     439
#    (...)
#     448     Vector containing the class labels for each sample.
#     449 """
#     450 xp, _ = get_namespace(X)
# --> 451 scores = self.decision_function(X)
#     452 if len(scores.shape) == 1:
#     453     indices = xp.astype(scores > 0, int)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:429, in LinearClassifierMixin.decision_function(self, X)
#     410 def decision_function(self, X):
#     411     """
#     412     Predict confidence scores for samples.
#     413
#    (...)
# ...

# %%
print(confusion_matrix(Y_validation, predictions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(confusion_matrix(Y_validation, predictions))
#
# NameError: name 'predictions' is not defined

# %%
print(classification_report(Y_validation, predictions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print(classification_report(Y_validation, predictions))
#
# NameError: name 'predictions' is not defined

# %%
X_new = pd.DataFrame({'diabetes': [10], 'BMI': [3], 'totChol': [5], 'glucose': [9]})
model.predict(X_new)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 X_new = pd.DataFrame({'diabetes': [10], 'BMI': [3], 'totChol': [5], 'glucose': [9]})
# ----> 2 model.predict(X_new)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:451, in LinearClassifierMixin.predict(self, X)
#     437 """
#     438 Predict class labels for samples in X.
#     439
#    (...)
#     448     Vector containing the class labels for each sample.
#     449 """
#     450 xp, _ = get_namespace(X)
# --> 451 scores = self.decision_function(X)
#     452 if len(scores.shape) == 1:
#     453     indices = xp.astype(scores > 0, int)
#
# File ~\anaconda3\Lib\site-packages\sklearn\linear_model\_base.py:429, in LinearClassifierMixin.decision_function(self, X)
#     410 def decision_function(self, X):
#     411     """
#     412     Predict confidence scores for samples.
# ...
